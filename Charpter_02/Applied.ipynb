# %% [markdown]
# # Chapter 2: Statistical Learning - Conceptual Exercises

# %% [markdown]
# ## Exercise 2.1:
#
# 1. For each of parts (a) through (d), indicate whether we would generally expect the performance of a flexible statistical learning method to be better or worse than an inflexible method. Justify your answer.
#
#     (a) The sample size n is extremely large, and the number of predic- tors p is small.
#
#     (b) The number of predictors p is extremely large, and the number of observations n is small.
#
#     (c) The relationship between the predictors and response is highly non-linear.
#
#     (d) The variance of the error terms, i.e. σ2 = Var(ε), is extremely high.
#
# ### Explanation
#
# (a) Expected Performance: Flexible Method Better
#
# Justification: With large 𝑛 and small 𝑝, low variance in flexible methods leads to better performance as they can learn complex patterns without overfitting.
#
# (b) Expected Performance: Flexible Method Worse
#
# Justification: With large 𝑝 and small 𝑛, flexible methods suffer from high variance and overfit, while inflexible methods provide bias-variance tradeoff favoring lower variance.
#
# (c) Expected Performance: Flexible Method Better
#
# Justification: Flexible methods handle non-linear relationships effectively due to their ability to model complex structures, unlike inflexible methods which assume linearity or simple forms.
#
# (d) Expected Performance: Flexible Method Worse
#
# Justification: High error variance causes flexible methods to overfit noise, resulting in poor generalization. Inflexible methods benefit from regularization and simplicity, reducing the impact of noise.
# ---

# %% [markdown]
# ## Exercise 2.2:
#
# 2. Explain whether each scenario is a classification or regression problem, and indicate whether we are most interested in inference or prediction. Finally, provide n and p.
#
#     (a) We collect a set of data on the top 500 firms in the US. For each firm we record profit, number of employees, industry and the CEO salary. We are interested in understanding which factors affect CEO salary.
#
#     (b) We are considering launching a new product and wish to know whether it will be a success or a failure. We collect data on 20 similar products that were previously launched. For each product we have recorded whether it was a success or failure, price charged for the product, marketing budget, competition price, and ten other variables.
#
#     (c) We are interested in predicting the % change in the USD/Euro exchange rate in relation to the weekly changes in the world stock markets. Hence we collect weekly data for all of 2012. For each week we record the % change in the USD/Euro, the % change in the US market, the % change in the British market, and the % change in the German market.
#
# ### Explanation
#
# (a) Model: Regression  Type: Inference  n = 500, p = 3
#
# (b) Model: Classification   Type: Prediction    n = 20, p = 13
#
# (c) Model: Regression   Type: Prediction n = 52, p = 3
#
# ---

# %% [markdown]
# ## Exercise 2.3:
#
# 3. We now revisit the bias-variance decomposition.
#
#     (a) Provide a sketch of typical (squared) bias, variance, training error, test error, and Bayes (or irreducible) error curves, on a single plot, as we go from less flexible statistical learning methods towards more flexible approaches. The x-axis should represent the amount of flexibility in the method, and the y-axis should represent the values for each curve. There should be five curves. Make sure to label each one.
#
#     (b) Explain why each of the five curves has the shape displayed in part (a).
#
# ### Explanation
#
# (a)

# %%
import matplotlib.pyplot as plt
import numpy as np

# Create a range for the x-axis representing flexibility
x = np.arange(0, 10, 0.5)

# Define the curves
# These are illustrative functions to mimic the general shapes of the curves
bias2 = (10 - x)**2 / 50  # Squared bias
variance = x**2 / 50  # Variance
training_error = 2 - 0.8*x + 0.2*x**2 - 0.02*x**3 + 0.0005 * x ** 4# Training error
test_error = bias2 + variance + 1  # Test error
bayes_error = np.full_like(x, 1)  # Bayes (irreducible) error

# Plot the curves
plt.figure(figsize=(10, 6))
plt.plot(x, bias2, label='Squared Bias', color='blue', linestyle='--')
plt.plot(x, variance, label='Variance', color='red', linestyle='-.')
plt.plot(x, training_error, label='Training Error', color='green', linestyle=':')
plt.plot(x, test_error, label='Test Error', color='purple', linestyle='-')
plt.plot(x, bayes_error, label='Bayes Error', color='orange', linestyle='-')

# Add labels and title
plt.xlabel('Flexibility')
plt.ylabel('Error')
plt.title('Bias-Variance Tradeoff and Error Curves')
plt.legend()

# Display the plot
plt.grid(True)
plt.show()

# %% [markdown]
# (b) (b) Explanation of Curve Shapes
#
# 1. Squared Bias: Initially decreases because more flexible models can capture complex patterns, reducing bias. However, it might flatten out or increase slightly as the model becomes too complex and starts overfitting.
#
# 2. Variance: Increases with flexibility because more flexible models are capable of fitting noise in the training data, leading to greater variability in predictions.
#
# 3. Training Error: Decreases with flexibility because more flexible models can better fit the training data, resulting in lower training error.
#
# 4. Test Error: Initially decreases due to reduced bias and improved fit to training data. However, it starts to increase as the model becomes overly complex and starts to overfit, leading to higher test error.
#
# 5. Bayes (Irreducible) Error: Remains constant because it represents the inherent noise or irreducible error in the data that cannot be eliminated by any model.
#
# ---

# %% [markdown]
# ## Exercise 2.4:
#
# 4. You will now think of some real-life applications for statistical learning.
#
#     (a) Describe three real-life applications in which classification might be useful. Describe the response, as well as the predictors. Is the goal of each application inference or prediction? Explain your answer.
#
#     (b) Describe three real-life applications in which regression might be useful. Describe the response, as well as the predictors. Is the goal of each application inference or prediction? Explain your answer.
#
#     (c) Describe three real-life applications in which cluster analysis might be useful.
#
# ### Explanation
#
# (a)
# 1. Heart Disease Risk Factors:
#
#     Inferencing whether blood cholesterol, smoking, daily physical activity and family background can impact risk of heart disease in patients.
#
# 2. Email spam:
#
#     Predicting wether an email is spam or not to filter them in inboxes based on email words and phrases, sender's email address, subject title and sender's IP.
#
# 3. Tumor malignancy
#
#     Predicting wether a tumor is malignant or begnin based on their cell-size, cell-shape, adhesion and presence of 5 other genes in thier DNA.
#
# (b)
#
# 1. House Price Prediction:
#
#     Predicting price of houses based on their square footage, age, levels and number of bedrooms.
#
# 2. Hospitalization cost of patients:
#
#     Inferencing whether reason of admission, patient's age and gender, body mass index (BMI) and number of childeren may effect hospitalization costs.
#
# 3. Electricity consumption:
#
#     Predicting electricity consumption rate of a city based on population, month of year, weather condition and economic activity
#
# (c)
#
# 1. Customer segmentation:
#
#     Grouping customers based on purchasing behaviour, demographic, ratings and preferences
#
# 2. Anomaly detection in pharmaceutical companies:
#
#     Identifying unsual productions based on their physical appearance, chemical laboratory tests and bacterial count
#
# 3. MRI brain tissue segmentation:
#
#     Segmenting brain cells in MRI images based on intenssity, texture, shape and morphology.
#
# ---

# %% [markdown]
# ## Exercise 2.5:
#
# 5. What are the advantages and disadvantages of a very flexible (versus a less flexible) approach for regression or classification? Under what circumstances might a more flexible approach be preferred to a less flexible approach? When might a less flexible approach be preferred?
#
# ### Explanation
#
# In general more flexible models are better choiuces in predicting and outcome, while less flexible models are suitable for inferecing challenges because of their interpretability. Very flexible approaches beside being computationally intensive, they are prone to overfitting due to their high variance and less flexible approaches are preffered when the dataset is small. Additionally, less flexible models are more suitable when the predictors and response have linear and simple relationship, while to detect complex and highly non-linear relation flexible models come in handy.
#
# ---

# %% [markdown]
# ## Exercise 2.6:
#
# 6. Describe the differences between a parametric and a non-parametric statistical learning approach. What are the advantages of a parametric approach to regression or classification (as opposed to a non-parametric approach)? What are its disadvantages?
#
# ### Explanation
#
# Parametric Approach:
#     A parametric approach to statistical learning involves assuming a specific form for the function that relates the predictors to the response. The model is characterized by a set of parameters, and learning involves estimating these parameters from the data.
#
# Non-Parametric Approach:
#     A non-parametric approach does not assume a specific form for the function relating the predictors to the response. Instead, it aims to learn the function directly from the data, allowing for more flexibility in capturing complex patterns.
#
# Advantages of Parametric Approaches:
#
# 1. Simplicity and Interpretability
#
# 2. Low Variance
#
# 3. Faster Computation
#
# 4. Avoid Overfitting
#
# Disadvantages of Parametric Approaches:
#
# 1. High bias (complex and non-linear dataset)
#
# 2. Inflexibility
#
# ---

# %% [markdown]
# ## Exercise 2.7:
#
# 7. The table below provides a training data set containing six observa- tions, three predictors, and one qualitative response variable.
#
# ![Screenshot 2024-07-16 at 18.34.58.png](<attachment:Screenshot 2024-07-16 at 18.34.58.png>)
#
# Suppose we wish to use this data set to make a prediction for Y when X1 = X2 = X3 = 0 using K-nearest neighbors.
#
# (a) Compute the Euclidean distance between each observation and thetestpoint,X1 =X2 =X3 =0.
#
# (b) What is our prediction with K = 1? Why?
#
# (c) What is our prediction with K = 3? Why?
#
# (d) If the Bayes decision boundary in this problem is highly non-linear, then would we expect the best value for K to be large or small? Why?
#
# ### Explanation
#
# (a):
#
# ![alt text](<Screenshot 2024-07-16 at 18.45.06.png>)
#
#
# ed_1 = 3, ed_2 = 2, ed_3 = 3.16, ed_4 = 2.24, ed_5 = 1.41, ed_6 = 1.73
#
# (b) For K=1, we look at the nearest neighbor. The nearest observation is:
#  Observation 5 with a distance of approximately 1.41 so the prediction is Red
#
# (c) For K=3, we look at the three nearest neighbors. The three nearest neighbors are:
#
# Observation 5 (distance = 1.41) - Green
#
# Observation 6 (distance = 1.73) - Red
#
# Observation 2 (distance = 2) - Red
#
# The prediction is Red because among the three nearest neighbors, two are Red, and one is Green. The majority class is Red.
#
# (d) If the Bayes decision boundary is highly non-linear, a small K is usually preferred. A small K allows the model to capture the complex, non-linear decision boundaries by being sensitive to local variations in the data.
#
# ---
